# %%
import matplotlib.pyplot as plt
import numpy as np


coordinates = np.array([
     [-3.6046457290649414, -134.84226989746094, 0.1],
                  [-14.538610458374023, -115.11746978759766, 0.1], 
                  [-43.23360824584961, -135.74557495117188, 0.1], 
                  [-129.53469848632812, -137.4750518798828, 0.1], 
                  [-129.56930541992188, -125.13030242919922, 0.1], 
                  [-42.6326904296875, -55.26836013793945, 0.1], 
                  [-39.80876922607422, -33.680824279785156, 0.1], 
                  [-15.820185661315918, -10.212478637695312, 0.1], 
                  [-20.03276252746582, -1.5320045948028564, 0.1], 
                  [-7.250657081604004, 3.4456217288970947, 0.1], 
                  [5.628537178039551, -3.233259916305542, 0.1], 
                  [44.842628479003906, 12.567604064941406, 0.1], 
                  [140.42613220214844, 11.990473747253418, 0.1], 
                  [141.41207885742188, -17.268627166748047, 0.1], 
                  [43.212745666503906, -62.90671920776367, 0.1], 
                  [34.97928237915039, -87.00750732421875, 0.1], 
                  [15.008147239685059, -98.59357452392578, 0.1], 
                  [22.417564392089844, -127.64183807373047, 0.1]
])

modefied_coordinates = coordinates.copy()
modefied_coordinates[:, 0] += 130
modefied_coordinates[:, 1] -= 15
modefied_coordinates[:, 1] *= -1

# %%
original_x = modefied_coordinates[:, 0]
original_y = modefied_coordinates[:, 1]

plt.figure(figsize=(10, 6))
plt.plot(original_x, original_y, 'ro-', label="Original Coordinates")  # Red dots and lines
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.title("Plot of Original Coordinates")
plt.legend()
plt.grid(True)
plt.show()

# %%
modefied_coordinates[:, 1] *= -1

print(modefied_coordinates)
# Out:
# [[ 1.26395354e+02 -1.49842270e+02  1.00000000e-01]
#  [ 1.15461390e+02 -1.30117470e+02  1.00000000e-01]
#  [ 8.67663918e+01 -1.50745575e+02  1.00000000e-01]
#  [ 4.65301514e-01 -1.52475052e+02  1.00000000e-01]
#  [ 4.30694580e-01 -1.40130302e+02  1.00000000e-01]
#  [ 8.73673096e+01 -7.02683601e+01  1.00000000e-01]
#  [ 9.01912308e+01 -4.86808243e+01  1.00000000e-01]
#  [ 1.14179814e+02 -2.52124786e+01  1.00000000e-01]
#  [ 1.09967237e+02 -1.65320046e+01  1.00000000e-01]
#  [ 1.22749343e+02 -1.15543783e+01  1.00000000e-01]
#  [ 1.35628537e+02 -1.82332599e+01  1.00000000e-01]
#  [ 1.74842628e+02 -2.43239594e+00  1.00000000e-01]
#  [ 2.70426132e+02 -3.00952625e+00  1.00000000e-01]
#  [ 2.71412079e+02 -3.22686272e+01  1.00000000e-01]
#  [ 1.73212746e+02 -7.79067192e+01  1.00000000e-01]
#  [ 1.64979282e+02 -1.02007507e+02  1.00000000e-01]
#  [ 1.45008147e+02 -1.13593575e+02  1.00000000e-01]
#  [ 1.52417564e+02 -1.42641838e+02  1.00000000e-01]]

# %%
track = np.array([(-2.1064330921476166, -135.84269944668037), (-13.186897278181053, -115.9389026680648), (-43.350383117938655, -135.021924321789), (-128.30060854419483, -134.40634297812045), (-128.30060854419483, -123.12068501086421), (-41.708832868155916, -55.201543426103854), (-43.350383117938655, -35.09255286626542), (-34.1166629629108, -22.165344649226448), (-17.90635424630639, -8.417361307296112), (-22.21542365198603, 0.6111650665089101), (-10.724571903506934, 8.203334971754018), (4.254574125760444, -0.20961005838245939), (32.981703496958225, 7.79294740930834), (41.599842308317484, 14.769535970884917), (147.47983341930342, 13.948760845993576), (148.50580232541762, -16.00953121254122), (132.91107495248167, -19.9082130557752), (71.7633281480751, -50.48208645797851), (75.86720377253194, -61.56255064401193), (61.708832868155916, -68.94952676803422), (52.68030649435094, -58.48464392566931), (43.036198776877384, -62.9989071125718), (44.47255524543728, -72.4378210488225), (37.49596668386066, -78.18324692306206), (38.93232315242055, -83.92867279730157), (13.693488062011141, -99.72859395146034), (20.259689061142048, -129.0713046663266)])
modefied_coordinates = np.array(track)
modefied_coordinates[:, 0] += 130
modefied_coordinates[:, 1] -= 15
modefied_coordinates[:, 1] *= -1

original_x = modefied_coordinates[:, 0]
original_y = modefied_coordinates[:, 1]

print(modefied_coordinates)

plt.figure(figsize=(10, 6))
plt.plot(original_x, original_y, 'ro-', label="Original Coordinates")  # Red dots and lines
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.title("Plot of Original Coordinates")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [[1.27893567e+02 1.50842699e+02]
#  [1.16813103e+02 1.30938903e+02]
#  [8.66496169e+01 1.50021924e+02]
#  [1.69939146e+00 1.49406343e+02]
#  [1.69939146e+00 1.38120685e+02]
#  [8.82911671e+01 7.02015434e+01]
#  [8.66496169e+01 5.00925529e+01]
#  [9.58833370e+01 3.71653446e+01]
#  [1.12093646e+02 2.34173613e+01]
#  [1.07784576e+02 1.43888349e+01]
#  [1.19275428e+02 6.79666503e+00]
#  [1.34254574e+02 1.52096101e+01]
#  [1.62981703e+02 7.20705259e+00]
#  [1.71599842e+02 2.30464029e-01]
#  [2.77479833e+02 1.05123915e+00]
#  [2.78505802e+02 3.10095312e+01]
#  [2.62911075e+02 3.49082131e+01]
#  [2.01763328e+02 6.54820865e+01]
#  [2.05867204e+02 7.65625506e+01]
#  [1.91708833e+02 8.39495268e+01]
#  [1.82680306e+02 7.34846439e+01]
#  [1.73036199e+02 7.79989071e+01]
#  [1.74472555e+02 8.74378210e+01]
#  [1.67495967e+02 9.31832469e+01]
#  [1.68932323e+02 9.89286728e+01]
#  [1.43693488e+02 1.14728594e+02]
#  [1.50259689e+02 1.44071305e+02]]
