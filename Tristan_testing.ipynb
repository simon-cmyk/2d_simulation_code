# %%
import matplotlib.pyplot as plt
import numpy as np


coordinates = np.array([
    [-3.604645729064941406, -134.84226989746094],
    [-14.53861045837402344, -115.11746978759766],
    [-43.23360824584960938, -135.74557495117188],
    [-129.534698486328125, -137.4750518798828],
    [-129.569305419921875, -125.13030242919922],
    [-42.6326904296875, -55.26836013793945],
    [-39.80876922607421875, -33.680824279785156],
    [-15.82018566131591797, -10.212478637695312],
    [-20.03276252746582031, -1.5320045948028564],
    [-7.250657081604003906, 3.4456217288970947],
    [5.628537178039550781, -3.233259916305542],
    [44.842628479003906, 12.567604064941406],
    [140.4261322021484375, 11.990473747253418],
    [141.412078857421875, -17.268627166748047],
    [43.21274566650390625, -62.90671920776367],
    [34.97928237915039062, -87.00750732421875],
    [15.00814723968505859, -98.59357452392578],
    [22.41756439208984375, -127.64183807373047]
])

modefied_coordinates = coordinates.copy()
modefied_coordinates[:, 0] += 130
modefied_coordinates[:, 1] -= 15
modefied_coordinates[:, 1] *= -1

# %%
original_x = modefied_coordinates[:, 0]
original_y = modefied_coordinates[:, 1]

plt.figure(figsize=(10, 6))
plt.plot(original_x, original_y, 'ro-', label="Original Coordinates")  # Red dots and lines
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.title("Plot of Original Coordinates")
plt.legend()
plt.grid(True)
plt.show()

# %%
modefied_coordinates[:, 1] *= -1

print(modefied_coordinates)
# Out:
# [[126.39535427 149.8422699 ]
#  [115.46138954 130.11746979]
#  [ 86.76639175 150.74557495]
#  [  0.46530151 152.47505188]
#  [  0.43069458 140.13030243]
#  [ 87.36730957  70.26836014]
#  [ 90.19123077  48.68082428]
#  [114.17981434  25.21247864]
#  [109.96723747  16.53200459]
#  [122.74934292  11.55437827]
#  [135.62853718  18.23325992]
#  [174.84262848   2.43239594]
#  [270.4261322    3.00952625]
#  [271.41207886  32.26862717]
#  [173.21274567  77.90671921]
#  [164.97928238 102.00750732]
#  [145.00814724 113.59357452]
#  [152.41756439 142.64183807]]
